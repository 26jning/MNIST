ning rate
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
# -----------------------------
# 4. TRAINING LOOP
# -----------------------------

# TODO: Define the number of epochs
epochs = 100

for epoch in range(epochs):
    model.train()
    total_loss = 0

    for images, labels in train_loader:
        # TODO: Reset the gradients
        optimizer.zero_grad()

        # TODO: Forward pass
        outputs = model(images)

        # TODO: Compute loss
        loss = criterion(outputs, labels)

        # TODO: Backpropagate
        loss.backward()

        # TODO: Update gradients
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")
# Out:
# Epoch 1, Loss: 437.4824
# Epoch 2, Loss: 212.5058
# Epoch 3, Loss: 160.1561
# Epoch 4, Loss: 127.7542
# Epoch 5, Loss: 106.6126
# Epoch 6, Loss: 91.8523
# Epoch 7, Loss: 80.0260
# Epoch 8, Loss: 70.7643
# Epoch 9, Loss: 64.1841
# Epoch 10, Loss: 57.3117
# Epoch 11, Loss: 52.2943
# Epoch 12, Loss: 48.0122
# Epoch 13, Loss: 43.9999
# Epoch 14, Loss: 40.6618
# Epoch 15, Loss: 37.5265
# Epoch 16, Loss: 34.5370
# Epoch 17, Loss: 31.8577
# Epoch 18, Loss: 29.7769
# Epoch 19, Loss: 27.5477
# Epoch 20, Loss: 25.6135
# Epoch 21, Loss: 23.5498
# Epoch 22, Loss: 22.2461
# Epoch 23, Loss: 20.4942
# Epoch 24, Loss: 19.0263
# Epoch 25, Loss: 17.9010
# Epoch 26, Loss: 16.5082
# Epoch 27, Loss: 15.4581
# Epoch 28, Loss: 14.5068
# Epoch 29, Loss: 13.7018
# Epoch 30, Loss: 12.5905
# Epoch 31, Loss: 12.0042
# Epoch 32, Loss: 11.0904
# Epoch 33, Loss: 10.4926
# Epoch 34, Loss: 9.9161
# Epoch 35, Loss: 9.3806
# Epoch 36, Loss: 8.6382
# Epoch 37, Loss: 8.3440
# Epoch 38, Loss: 7.8429
# Epoch 39, Loss: 7.3434
# Epoch 40, Loss: 6.9499
# Epoch 41, Loss: 6.5982
# Epoch 42, Loss: 6.3243
# Epoch 43, Loss: 6.0145
# Epoch 44, Loss: 5.7016
# Epoch 45, Loss: 5.4515
# Epoch 46, Loss: 5.2265
# Epoch 47, Loss: 4.9850
# Epoch 48, Loss: 4.7797
# Epoch 49, Loss: 4.6084
# Epoch 50, Loss: 4.3891
# Epoch 51, Loss: 4.2022
# Epoch 52, Loss: 4.0520
# Epoch 53, Loss: 3.9279
# Epoch 54, Loss: 3.7786
# Epoch 55, Loss: 3.6792
# Epoch 56, Loss: 3.4940
# Epoch 57, Loss: 3.4293
# Epoch 58, Loss: 3.3161
# Epoch 59, Loss: 3.1985
# Epoch 60, Loss: 3.1080
# Epoch 61, Loss: 3.0109
# Epoch 62, Loss: 2.9185
# Epoch 63, Loss: 2.8475
# Epoch 64, Loss: 2.7691
# Epoch 65, Loss: 2.6881
# Epoch 66, Loss: 2.6100
# Epoch 67, Loss: 2.5470
# Epoch 68, Loss: 2.4917
# Epoch 69, Loss: 2.4416
# Epoch 70, Loss: 2.3539
# Epoch 71, Loss: 2.3122
# Epoch 72, Loss: 2.2601
# Epoch 73, Loss: 2.1993
# Epoch 74, Loss: 2.1277
# Epoch 75, Loss: 2.1050
# Epoch 76, Loss: 2.0511
# Epoch 77, Loss: 2.0128
# Epoch 78, Loss: 1.9774
# Epoch 79, Loss: 1.9383
# Epoch 80, Loss: 1.8940
# Epoch 81, Loss: 1.8560
# Epoch 82, Loss: 1.8142
# Epoch 83, Loss: 1.7799
# Epoch 84, Loss: 1.7428
# Epoch 85, Loss: 1.7206
# Epoch 86, Loss: 1.6792
# Epoch 87, Loss: 1.6503
# Epoch 88, Loss: 1.6215
# Epoch 89, Loss: 1.5883
# Epoch 90, Loss: 1.5696
# Epoch 91, Loss: 1.5346
# Epoch 92, Loss: 1.5112
# Epoch 93, Loss: 1.4819
# Epoch 94, Loss: 1.4635
# Epoch 95, Loss: 1.4436
# Epoch 96, Loss: 1.4102
# Epoch 97, Loss: 1.3863
# Epoch 98, Loss: 1.3621
# Epoch 99, Loss: 1.3541
# Epoch 100, Loss: 1.3284

# %%
# -----------------------------
# 5. EVALUATION
# -----------------------------
correct = 0
total = 0
model.eval()

with torch.no_grad():
    for images, labels in test_loader:
        # TODO: Forward pass
        outputs = model(images)

        # Predicted class = index of max logit
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Test Accuracy: {100 * correct / total:.2f}%")
# Out:
# Test Accuracy: 98.07%

# %%
# -----------------------------
# 6. TEST SINGLE PREDICTION
# -----------------------------
# -----------------------------
# 6. TEST SINGLE PREDICTION
# -----------------------------
# ------------------------------
# Gradio Sketchpad gives you:

# * a full-color NumPy array

# * black digit on white background

# * large resolution

# * no consistent scale
#
# Hence the preprocessing
# ------------------------------

import gradio as gr
from PIL import Image, ImageOps

def preprocess_image(image):
    sketch_transform = transforms.Compose([
    transforms.ToPILImage(),                      # NumPy → PIL
    transforms.Grayscale(),                       # ensure 1 channel
    transforms.Resize((28, 28)),                  # 28x28 like MNIST
    transforms.Lambda(lambda img: ImageOps.invert(img)),  # invert colors
    transforms.ToTensor(),                        # → tensor, shape (1,28,28), values in [0,1]
    ])
    # Gradio Sketchpad sometimes passes a dict with 'composite'
    if isinstance(image, dict):
        image = image['composite']   # this is a NumPy array

    # Apply the preprocessing transform
    img_tensor = sketch_transform(image)  # (1, 28, 28)

    # Add batch dimension → (1, 1, 28, 28)
    img_tensor = img_tensor.unsqueeze(0)

    return img_tensor

def predict_digit(image):
    # --- STEP 1: CHECK IF SOMETHING HAS BEEN DRAWN ---
    if image is None: return "Draw something!"

    # --- STEP 2: PREPROCESS THE IMAGE ---
    img_tensor = preprocess_image(image)

    # --- STEP 3: RUN THE MODEL ---
    with torch.no_grad():
        prediction = model(img_tensor)

        # Get the index of the highest score (the predicted digit)
        predicted_digit = torch.argmax(prediction).item()

    return str(predicted_digit)

# UI Setup
interface = gr.Interface(fn=predict_digit, inputs=gr.Sketchpad(label="Draw Here"), outputs="label")
interface.queue().launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://56ba7a9b0bb584c24a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://56ba7a9b0bb584c24a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
